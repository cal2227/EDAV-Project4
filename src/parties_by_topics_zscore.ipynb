# %%
import pandas as pd
import seaborn as sb
import numpy as np
import nltk
import utils

# %%
# %matplotlib inline

# %%
stemmed_keywords = utils.get_stemmed_keywords()

# %%
df = pd.read_json(utils.suas_with_topic_frequencies)

# %%
# drop jimmy carter written sua
df = df[df['year'] != 1981]

# %%
df['environment'].mean(), df['environment'].std()
# Out:
# (7.0, 3.7172815091383407)

# %%
for topic in stemmed_keywords.keys():
    df[topic] = (df[topic] -df[topic].mean()) / df[topic].std()

# %%
sb.lmplot('year', 'defense', data=df, hue='political_party', fit_reg=True)

# %%
sb.lmplot('year', 'economy', data=df, hue='political_party', fit_reg=True)

# %%
sb.lmplot('year', 'education', data=df, hue='political_party', fit_reg=True)
