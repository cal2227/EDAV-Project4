# %%
from matplotlib import pyplot as plt

import nltk

import utils

# %%
# %matplotlib inline

# %%
suas = utils.get_suas_1970()

# %%
cfd = nltk.ConditionalFreqDist(
    (target, sua['year'])    
    for sua in suas    
    for w in nltk.word_tokenize(sua['text'])
    for target in ['immigra', 'border']
    if w.lower().startswith(target))

# %%
cfd.plot()

# %%
cfd2 = nltk.ConditionalFreqDist(
    (target, sua['year'])    
    for sua in suas    
    for w in nltk.word_tokenize(sua['text'])
    for target in ['mexico','china','india']
    if w.lower().startswith(target))

# %%
cfd2.plot()

# %%
[sua['year'] for sua in suas]
# Out:
# [1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1990,
#  1991,
#  1992,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016]
