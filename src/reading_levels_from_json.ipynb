# %%
from matplotlib import pyplot as plt
import seaborn as sb
import pandas as pd

import utils

# %%
# %matplotlib inline

# %%
df = pd.read_json(utils.with_presidents_fname)

# %%
f, axarr = plt.subplots(8, figsize=(15,40))
for i, key in enumerate(utils.reading_level_keys):
    sb.regplot('year', key, data=df, ax=axarr[i], fit_reg=False)
    #plt.show()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.3/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'GunningFogIndex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-fdb889163111> in <module>()
#       1 f, axarr = plt.subplots(8, figsize=(15,40))
#       2 for i, key in enumerate(utils.reading_level_keys):
# ----> 3     sb.regplot('year', key, data=df, ax=axarr[i], fit_reg=False)
#       4     #plt.show()
#       5 plt.show()
#
# /usr/local/lib/python3.3/site-packages/seaborn/linearmodels.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     764                                  order, logistic, lowess, robust, logx,
#     765                                  x_partial, y_partial, truncate, dropna,
# --> 766                                  x_jitter, y_jitter, color, label)
#     767
#     768     if ax is None:
#
# /usr/local/lib/python3.3/site-packages/seaborn/linearmodels.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     103         # Extract the data vals from the arguments or passed dataframe
#     104         self.establish_variables(data, x=x, y=y, units=units,
# --> 105                                  x_partial=x_partial, y_partial=y_partial)
#     106
#     107         # Drop null observations
#
# /usr/local/lib/python3.3/site-packages/seaborn/linearmodels.py in establish_variables(self, data, **kws)
#      48         for var, val in kws.items():
#      49             if isinstance(val, string_types):
# ---> 50                 setattr(self, var, data[val])
#      51             else:
#      52                 setattr(self, var, val)
#
# /usr/local/lib/python3.3/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /usr/local/lib/python3.3/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.3/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /usr/local/lib/python3.3/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python3.3/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'GunningFogIndex'
